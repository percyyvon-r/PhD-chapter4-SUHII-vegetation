# %% [markdown]
# # Chapter 4 SUHII & Vegetation
#
# This notebook is the starting point for exploratory analysis of SUHII and vegetation metrics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('Hello Chapter 4 SUHII Vegetation')
# Out:
# Hello Chapter 4 SUHII Vegetation

# %% [markdown]
# # Prepare data

# %%
# Load the Land cover per LCZ data
land_cover_data = pd.read_csv('../data/csv/01_lc_lcz_tabulate_area_csv.csv')

# Load the SUHII data
suhii_data = pd.read_csv('../data/csv/03_lst_suhi_zonal_csv.csv')
